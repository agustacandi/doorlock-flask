# %%
import cv2
import matplotlib.pyplot as plt

# Read image
img = cv2.imread("C:/Users/fthnm/OneDrive/Pictures/20231030_102907_mfnr.jpg")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = cv2.resize(img_rgb, (224, 224))
# plt.imshow(img)
plt.imshow(img_rgb)
plt.show()

print(img_rgb.shape)
# Out:
# (224, 224, 3)
